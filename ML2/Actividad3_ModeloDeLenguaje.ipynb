# %% [markdown]
# # Actividad 3: Modelo de Lenguaje
#
# ### **Construye una Red Neuronal Recurrente o Transformer para una tarea de generación de texto.**
#
# En esta actividad por grupos, teneis que construir una Red Recurrente Elman, LSTM, GRU, o un Transformer (a elegir), que entrenareis con un dataset de texto (también a elegir). Una vez entrenado, el modelo tiene que ser capaz de generar texto.
#
# **Para aprobar, el código debe ejecutar sin errores importantes** (no pasa nada por algun warning leve de pytorch), la red se debe entrenar y la función de perdida disminuir. Por último, en la inferencia, **la red debe ser capaz de imprimir texto**.
#
# **No hay ningún requisito de calidad del texto generado**. Modelar bien el lenguaje humano es una tarea excepcionalmente complicada y que requiere de mucha capacidad de procesamiento y una gran cantidad de datos. No espero que ninguno de los textos generados tenga sentido. Aún así, se valorará positivamente que el texto generado tenga un parecido razonable con tener algo de coherencia.
#
# Este es un ejercicio más complicado que las actividades previas, pero es en grupo, y disponeis de más tiempo, semana y media. Aconsejo partir de los ejercicios resueltos, leerlos y entenderlos, y tocar poco a poco el código, para ver que efecto tiene. Si os atascais, no dudeis en publicar vuestras dudas en el tablon para que otros alumnos o el profesor os pueda ayudar.
#
# **La entrega de la actividad será el archivo del cuaderno de Jupyter (archivo .ipynb). Puede descargarse desde Archivo > Descargar > Descargar .ipynb**. Si usais algun archivo para entrenar que tengais en vuestro PC, debeis entregar tambien ese archivo.

# %%
# importamos la libreria pytorch
import torch
from torch import nn
from torch import optim #las funciones de optimizacion (gradient descent)
from torch.optim.lr_scheduler import StepLR #learning rate decay
import torch.nn.functional as F #convencion
from torchvision import datasets, transforms

# matplotlib para pintar graficas
import matplotlib.pyplot as plt
# %matplotlib inline

# para poder descargar el dataset desde una URL
# o leerlo de tu PC. si el archivo es local,
# # por favor mandadlo junto con el cuaderno .ipynb
# # para que en la correccion pueda replicar vuestro entrenamiento
import requests
from io import open
import string # Import the string module for punctuation handling

# %%
# usamos la GPU si esta disponible
if torch.cuda.is_available():
  device = torch.device("cuda")
  print("Dispositivo usado: GPU con CUDA")
else:
  device = torch.device("cpu")
  print("Dispositivo usado: CPU")
# Out:
# Dispositivo usado: GPU con CUDA

# %%
# el diccionario es una estructura de datos
# que guarda la relación palabra <-> id de token
class Dictionary(object):
    def __init__(self):
        self.token2idx = {}
        self.idx2token = []

    # añadir un token al diccionario
    def add_token(self, token):
        # si un token no estaba en el diccionario
        # se añade su entrada
        if token not in self.token2idx:
            self.idx2token.append(token)
            self.token2idx[token] = len(self.idx2token) - 1
        return self.token2idx[token]

    # funcion que devuelve el tamaño del diccionario
    # (cuantos tokens distintos hay)
    def __len__(self):
        return len(self.idx2token)

    # imprimir la lista de tokens distintos
    def __repr__(self):
        string = ""
        for char in sorted(self.idx2token):
            string += char
        return string

class Corpus(object):
    def __init__(self):
        self.dictionary = Dictionary()

        # URLs con el texto (son archivos .txt)
        url_train = "https://gist.githubusercontent.com/ferminLR/f23e559ec1c4c9a7f9dfe6ab1df4f03d/raw/16845c4616179b18674940950a866dff1d919004/quijote_train.txt"
        url_test = "https://gist.githubusercontent.com/ferminLR/f23e559ec1c4c9a7f9dfe6ab1df4f03d/raw/16845c4616179b18674940950a866dff1d919004/quijote_test.txt"
        url_validation = "https://gist.githubusercontent.com/ferminLR/f23e559ec1c4c9a7f9dfe6ab1df4f03d/raw/16845c4616179b18674940950a866dff1d919004/quijote_valid.txt"

        # se pasa el texto del .txt a la funcion tokenize()
        self.train = self.tokenize(requests.get(url_train).text)
        self.validation = self.tokenize(requests.get(url_validation).text)
        self.test = self.tokenize(requests.get(url_test).text)

        print("conversion a tokens completada!")
        print(len(self.dictionary), "tokens distintos en el diccionario:")
        print(self.dictionary)
        print(self.train.shape[0], "tokens en el split de train")

    # tokeniza el texto
    def tokenize(self, text):

        # lista donde se va a guardar la secuencia de texto convertida en tokens
        tokenseq = []

        # añadir los tokens al diccionario (por si todavia no estan)
        # modelo de lenguaje a nivel de caracteres = los tokens son caracteres
        for line in text:
            for char in line:
                self.dictionary.add_token(char) # se añade cada caracter al diccionario

        # convertimos a tokens cada caracter del texto
        for line in text:
            # ids = []
            for char in line:
                tokenseq.append(torch.tensor(self.dictionary.token2idx[char]).type(torch.int64))

        # se convierte tokenseq a un tensor de pytorch
        embed = torch.tensor(tokenseq)
        return embed

block_size = 32 # tamaño de contexto, lo que mira hacia atras el modelo para hacer una prediccion
batch_size = 16 # batches, cuantas secuencias de texto se procesan a la vez

# genera un par de datos de entrada y targets correspondientes
# el target es el texto desplazado un caracter
def get_batch(source):
    data = source
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
# el diccionario es una estructura de datos
# que guarda la relación palabra <-> id de token
class Dictionary(object):
    def __init__(self):
        self.token2idx = {}
        self.idx2token = []

    # añadir un token al diccionario
    def add_token(self, token):
        # si un token no estaba en el diccionario
        # se añade su entrada
        if token not in self.token2idx:
            self.idx2token.append(token)
            self.token2idx[token] = len(self.idx2token) - 1
        return self.token2idx[token]

    # funcion que devuelve el tamaño del diccionario
    # (cuantos tokens distintos hay)
    def __len__(self):
        return len(self.idx2token)

    # imprimir la lista de tokens distintos
    def __repr__(self):
        # Modified for word-level tokenization to prevent extremely long output
        if len(self.idx2token) > 20: # show a sample if dictionary is large
            return f"Dictionary with {len(self.idx2token)} tokens. Sample: {self.idx2token[:5]} ... {self.idx2token[-5:]}"
        else:
            return f"Dictionary with {len(self.idx2token)} tokens: {self.idx2token}"

class Corpus(object):
    def __init__(self):
        self.dictionary = Dictionary()
        # Add <unk> token first for out-of-vocabulary words
        self.dictionary.add_token('<unk>')

        # URLs con el texto (son archivos .txt)
        url_train = "https://gist.githubusercontent.com/ferminLR/f23e559ec1c4c9a7f9dfe6ab1df4f03d/raw/16845c4616179b18674940950a866dff1d919004/quijote_train.txt"
        url_test = "https://gist.githubusercontent.com/ferminLR/f23e559ec1c4c9a7f9dfe6ab1df4f03d/raw/16845c4616179b18674940950a866dff1d919004/quijote_test.txt"
        url_validation = "https://gist.githubusercontent.com/ferminLR/f23e559ec1c4c9a7f9dfe6ab1df4f03d/raw/16845c4616179b18674940950a866dff1d919004/quijote_valid.txt"

        # Load raw text
        raw_train_text = requests.get(url_train).text
        raw_validation_text = requests.get(url_validation).text
        raw_test_text = requests.get(url_test).text

        # First pass: build dictionary from all available text to ensure all words are mapped
        full_text_for_dict = raw_train_text + raw_validation_text + raw_test_text
        words_for_dict = self._split_text_into_words(full_text_for_dict)

        for word in words_for_dict:
            self.dictionary.add_token(word)

        # Now tokenize each split into sequences of word IDs
        self.train = self._tokenize_words_to_ids(raw_train_text)
        self.validation = self._tokenize_words_to_ids(raw_validation_text)
        self.test = self._tokenize_words_to_ids(raw_test_text)

        print("conversion a tokens completada!")
        print(len(self.dictionary), "tokens distintos en el diccionario:")
        print(self.dictionary) # This will now print the concise representation
        print(self.train.shape[0], "tokens en el split de train")

    # Helper method to split text into words using regex
    def _split_text_into_words(self, text):
        # Convert to lowercase
        text = text.lower()
        # This regex captures sequences of alphanumeric characters (words),
        # or sequences of non-alphanumeric, non-whitespace characters (punctuation),
        # or newline characters. This ensures punctuation is treated as separate tokens.
        words = re.findall(r'\b\w+\b|[^\s\w]+|\n', text)
        # Filter out empty strings that might result from regex if there are multiple spaces
        return [word for word in words if word.strip()]

    # Modified tokenization method to handle words
    def _tokenize_words_to_ids(self, text):
        tokenseq = []
        words = self._split_text_into_words(text)

        for word in words:
            # Get the index of the word, if not found, use the <unk> token's index
            token_id = self.dictionary.token2idx.get(word, self.dictionary.token2idx['<unk>'])
            tokenseq.append(torch.tensor(token_id).type(torch.int64))

        # se convierte tokenseq a un tensor de pytorch
        embed = torch.tensor(tokenseq)
        return embed

block_size = 32 # tamaño de contexto, lo que mira hacia atras el modelo para hacer una prediccion
batch_size = 16 # batches, cuantas secuencias de texto se procesan a la vez

# genera un par de datos de entrada y targets correspondientes
# el target es el texto desplazado un caracter
def get_batch(source):
    data = source
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
# carga de datos y generacion de diccionario
corpus = Corpus()
ntokens = len(corpus.dictionary)

# convertir los datos en batches
train_data = corpus.train
validation_data = corpus.validation
test_data = corpus.test
# Out:
# conversion a tokens completada!
# 23052 tokens distintos en el diccionario:
# Dictionary with 23052 tokens. Sample: ['<unk>', 'miguel', 'de', 'cervantes', 'saavedra'] ... ['callos', 'viertan', 'quédente', 'raigones', 'sacares']
# 355378 tokens en el split de train

# %%
# Hiperparámetros de la red
# reducir n_embd, n_layer y epochs si no se usa GPU
# en CPU tardaría mucho el entrenamiento
# n_head tiene que ser divisor de n_embd

n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0

# una cabeza de atencion
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()

        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)

        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape

        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)

        # calcula la puntuacion de atencion
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)

        # mascara para no atender al futuro
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)

        # salida del operador de atencion
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)

        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()

        # lista con las cabezas de atencion
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # el resultado de las cabezas se concatena a la salida
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

# bloque de un transformer
# atencion + mlp + sus residual connections
class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()

        # el tamaño de cada cabeza de atencion es el
        # tamaño del embedding dividido por el tamaño de cada cabeza
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)

        # MLP
        self.ffwd = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

        # layer normalization
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        # suma -> conexion residual
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


vocab_size = ntokens

class Transformer(nn.Module):

    def __init__(self):
        super().__init__()

        # input embedding
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)

        # positional encoding
        self.position_embedding_table = nn.Embedding(block_size, n_embd)

        # transformer blocks (decoders)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])

        # layer normalization
        self.ln_f = nn.LayerNorm(n_embd)

        # mlp al final
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, input, targets=None):
        B, T = input.shape

        # input embedding + positional encoding
        tok_emb = self.token_embedding_table(input)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb

        # decoder blocks
        x = self.blocks(x)

        # layer normalization final
        x = self.ln_f(x)

        # mlp al final
        logits = self.lm_head(x)

        # si no hay targets (inferencia), no hay loss
        if targets is None:
            loss = None
        else:
            # calculo de la perdida
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

# %%
# inferencia
def generate_text():
    # configurar el modelo en modo evaluacion o inferencia
    # se necesita para que capas como batchnorm o dropout se comporten correctamente
    model.eval()

    # generamos un input aleatorio
    input_token_id = torch.randint(ntokens, (1, 1), dtype=torch.long).to(device)
    input_sequence = input_token_id

    generated_tokens = []
    # Obtenemos el primer token y lo añadimos a la lista
    first_token = corpus.dictionary.idx2token[input_token_id.item()]
    generated_tokens.append(first_token)

    with torch.no_grad():
        # escribimos 'chars' tokens
        for i in range(chars - 1): # Generate chars-1 more tokens, as one is already generated

            # se ejecuta el modelo
            # Solo pasamos la parte relevante de la secuencia (últimos block_size tokens)
            input_block = input_sequence[:, -block_size:]
            output, _ = model(input_block)
            output = output[:,-1,:] # Obtenemos la predicción para el último token
            probs = F.softmax(output, dim=-1)

            # se saca el siguiente token a partir de la distribución de probabilidades
            input_next_id = torch.multinomial(probs, num_samples=1)
            input_sequence = torch.cat([input_sequence, input_next_id], dim=1)

            next_token = corpus.dictionary.idx2token[input_next_id.item()]
            generated_tokens.append(next_token)

    # Formatear y imprimir el texto generado para que sea legible
    final_text_raw = ""
    if generated_tokens:
        final_text_raw += generated_tokens[0]

    for i in range(1, len(generated_tokens)):
        token = generated_tokens[i]
        previous_token = generated_tokens[i-1]

        if token == "\n":
            final_text_raw += "\n"
        elif token in string.punctuation:
            # Si el token actual es puntuación, y el carácter anterior es un espacio,
            # eliminamos ese espacio antes de añadir la puntuación.
            if final_text_raw and final_text_raw[-1] == ' ':
                final_text_raw = final_text_raw[:-1]
            final_text_raw += token
        else: # El token actual es una palabra
            # Si el token anterior no era un salto de línea, añadimos un espacio.
            if previous_token != "\n":
                final_text_raw += " "
            final_text_raw += token

    # Añadir saltos de línea cada 15 palabras para mejor legibilidad
    words = final_text_raw.split(' ')
    formatted_text = []
    current_line_word_count = 0
    for word in words:
        if "\n" in word: # Handle explicit newlines
            parts = word.split("\n")
            for j, part in enumerate(parts):
                if part:
                    formatted_text.append(part)
                if j < len(parts) - 1:
                    formatted_text.append("\n")
                current_line_word_count = 0 # Reset word count after a newline
        else:
            formatted_text.append(word)
            current_line_word_count += 1

        if current_line_word_count >= 15:
            formatted_text.append("\n")
            current_line_word_count = 0

    print(' '.join(formatted_text).replace(' \n ', '\n').replace('\n ', '\n'))

# %%
# Como se comporta la red neuronal antes de entrenar?

# semilla del generador de numeros aleatorios
# para conseguir resultados deterministas
torch.manual_seed(42)

# inicializamos el modelo
model = Transformer()
model.to(device)

# configuramos como de largo queremos que sea el texto
chars = 2000

generate_text()
# Out:
# votaba picante exagerando desgarrase llantos acogido otubre miradlo trabajaba fingidamente obligarse gruesa dilatados imaginarse toledano
# ejecutallos medíme médiese sierpes aplace pascua merece romperlo responderla convidó desabrochándole tan negligencia canillas entretenimiento
# descubrirme embebían digresiones nacía presentósela capítulo trataban bando pasajeros idea marca picados terribles gayos leer
# aplauso guío auto sosegasen cañutillos pulsat campanas quedáronse santiago imagen credite honran convidador averiguo escurriendo
# refiere esperándola dádivas diputó solene pentapolén obligar hundirme mientras pasajera pasado fijo olvidándome fío seso
# trataron quejarme inconstancia gallinas objeciones admiróme variar ahorcamos lamente admitido partieron ultramarino pídanmelo aullidos zumban
# observaciones suave cuenta aclamaron supimos oídas aromático cañón madésima luenga ensartado muéveme fermosa derribó zafia
# seguid sepulcro mostrasen titulillos florentibus maltratando cerbelo preguntaremos barruntos misterios varones hiciéronle laguna conservar acabaremos
# desamparo volverte trómpogelas estimaran cabos recogimiento alojó desta faltaren haces espilorchería harán llego confesad felix
# perfeta queriéndose quiérole enarboló escondidas publica barajan inremediable maridos laguna sabíamos fílidas admiraba engolfarte engaño
# obedecerte inspiración comencé librar fastidio poseían valían capaz carricoche modestia colorados círculos hebras párpados dársela
# esperamos blancos anduviera mi anublar joventud ladearme desoluto montemayor vitorias prendéis gozarás encamine salterios llamarla
# ofreciere sean miró despertó francolines opinión lamentes mostraras mentironiana encubrirme sacársele podar bebidas doña proponía
# derribado anteón pertrechando nabos laida pródigo persuadida alforjas madásimas cebollinas estrechísimamente morirme incurable dejárame respondieron
# censos arroz darla varas camoes zamorano trillando in sabios agradeciólo gozques argumentos envié felicísima retiré
# diósela llegaré dártela establecida dotes fuertemente guardábala quisiese dándolos receloso seis atinar partiesen muda remediados
# enterándose satisfago palomas resucitara justicia trasquiló verás deleitables arroja mesas postrada pésame profetizadas guilla encomendar
# mamaron delicadas juramento otorga don emperadores combaten causaba pífaro malnacida letra vuesa mismo ballestas varapalos
# dese gobernarlos islas nombrar vistióse vivían acordar zeuxis lastimeros altibajo delgado tudesqui despuntes culpado dificultades
# triunfe abarraganada transportado familiar sacara amargo habréis quitan brío paganos nos íbades abrasados estimarse ah
# saldría encubrió relatando prisión mandárselo sevillano preguntaremos contase anocheció guardaban bazán sabroso grebas cristianesca alcornoqueñas
# stultorum barriendo chirrío pichones quebrantamiento almena reventaba peleamos compres discurre contornos pégate leal satanases apócrifos
# toraquís estera formarse encomiendo caba heredase favor belicosos ruégote estacazos frazada agüelos embarazoso leyera alojaba
# residencia ofrecieron proezas persuadirme ordenanzas aprovechase reducirte sobrevista acompañador diputo ordenarse dé picaban zeuxis trujera
# inefable acompañasen eran eficacia portogal serrallo calentura aprovechó socaliñas salves bailador celoso envidar pastores hirióle
# cardenales visitáronle gentes saboreándose yugadas cantos confirmar sudaba novios suplicar derramando declaran valerse honralle fez
# heredado discurren dejes memorable pagárnoslo debe faltare cubrir trabajos viajes importunan va cocido olvida favorecían
# sacaba valdovinos impura minas espuela mala mostrad regida pulgas pliegos gallardetes imposibilitado sirviesen adoró guiados
# sahumerio setenta aprisionado malparado empache comunicallo favores obligadísimo disparatados sastres espantajo ayudarle yacer traidores orgulloso
# sosegasen juramento escopeteros negregura desnudarnos trató pata jerez ayudaría cumplían parecióles segundara convidó vendiere rodelas
# conjeturando quererlos encerráronse luscinda caja notó imágenes pecaron imitación llantos encinar alborotarían ajustará carecieron alto
# poseían marqués gasaje hablamos traspásenme bollo andan alientos inventor perdí prestada correspondiéndoles artús sepades maravilla
# espero enceradas mentirosas acudían polaco encerrar molieron pesará adornar diciembre saludes alcanzándoles conocí hablándolos arroz
# tabla acogía escaseza echaron ferro habilidad votos quantioso romper vosotras abríla vivid manifestarse so encajó
# vates prosa encuéntrase peligro !» tener dibu orianas lucidísimo señoríos alborotarse destruir significaba bartolomé valentísimo
# satisfechos alzados sincero estorbase coligieron memorioso tomóse ocupado alcanzadas engendrada dejaba guijeñas rencuentro decreta acompañadas
# echaréis felipe portaba suma dictaba calar viéredes agasajado anillos candiles colcha dueños suspiró darinel tundas
# exhalaciones hallarse aposento veneración faquín herreros quitara docenas prosiguen respondemos recelo ., lleva pudieron corro
# vecinos atravesando bebiere solazando picó bota tracia fióle perdonaros emplastado hebras estarse convidador recogían acontecido
# heridas registro hilas venciéndose almendras arrastró costosa voltaria ausente templóse encomendarle combatidos peones fingían mudase
# doliese azotan despedió discurren oílle secreto escribistes rodar reliquia válgame ose generales hacha consiste castas
# remirado mandamientos per caballerescas pistolas rapadas ahuyentado quitándole tire desvalidos honesto pareció importunarle mantellina limpias
# volverle tengáis mandándoles desmayar dispone haberlos cerrasen juzgaron randas informaba borracho desplegó señalaba corvetas traspuesta
# entiéndase guelte prosperidades magnánimo chusma fijo respondiéronme perjudiciales imaginadas dubitat noriz deténgome pusiere ventajas cogiéronlos
# tirante endechando ayudara callejuelas renovar consideró rabiaba lomos semanas pena escribieron entrego satisfice desusados revocar
# envié animalejo estampado trataba altercaciones cojín buscadas nace hicieras mármol confundidas oh avellanado tendiéronse importantes
# épica tazas abrazamiento mala rebuznaron avisé fuesen ahechar infundir vómito paralipomenón faltaron enviarle limpiarme reducida
# opinión descuidarse ensalada señoría entregué latino mohinísimo propuso entendieron público unció regaladísimo mostrar labrandera fléridas
# plutarco encaminaban riñeren longincuos aguardase indicio podrida ?. huyóse levantéis dominio ocupada averiguo gigante bonico
# siesta grandísimos volvimos pesado entregándolos miradas colocadas prudentes hojeé agradare espantan hacelle pasó llegada ""¡
# sobrescrito atento doliese preguntáronme agobiada pesan verde despedido publica alano grosera probáis estaría congojado corté
# rota virtuosa podrá empleadísima ganancioso demos traspásasele parcialidad quede artificiosos proveídas conmigo molido grabe entienda
# atropellado dénsele pasear primavera adornadas pueblos habrían encerraba avise favoreciesen estudiantado mojicón necio maldonado holgué
# esfogue truchuela universidad invisible procuralle irán generales curioso venza almejas sucedernos esotros malencónicas sacaste carniceros
# melena sansonino llevarles bota roble alborozado contentarse graznar presencias guadarrama noramala empresas gabrio garcía eficacísimas
# considera emprenta semeja ablandó cartagena mateo rasgados excediese defender poderlo deseábamos caminantes trova ponerlos confesor
# procurador muchachas verlas enseñábale maten reprehensiones desuellacaras embebecido montesinos trató engendraren conocemos quintanar da enterarme
# combatiente atemoricen sola pedid juró frisada febo carnes embotan socarronamente profesado !'', dolor tuvo monteros
# comenzando temía convidó asaduras deshora tuerza apellidarían xlii invidiara entretuviera grado debióse votos berbería nombráis
# ándeme comenzaba ganándola empapado trasladen contentaba ojeras debilidad vasallo yelan reduciéndolo preció acometían descubrimos peligrosas
# conquisto acostar comunicación pretendo moral pasaba amohinábase perderse esperaban improvisa huelgo parasismo cuadros vestirte medrosica
# llamaste graduaron acercando tardaremos acobarde báculo inventores dulzainas noté callasen calumnias portogal acababa sufridor alcanzarlo
# estendió gana dormitando apartamiento suplicamos defienda dices manejan acaballe ijas ...''; hilar subamos voacé abrí
# medianas acaecimientos nadando salió amanecerá sabiendo rogarále mares diéronles pesaba morisco sansón despedía sosegáronse descaminada
# atadura semblante picos enternecerle desvelado turquesco atrae saberse preguntan remedio caja coser dilataba lloveré pajes
# sotilmente oiga deciendo celosa cimiento burladora véngote nueve andes truhán ijas volátiles bola cena hombruno
# recogiéndolas estimarme igual vejigas aditamento leamos reprochado lot diéronle nuncio encenderme verterlas fantásticos yerran alumbres
# cerraduras llamóse palaciega soltarte triunfante alzaste estiendan melancolía guardarropas destrae traducirlos balbastro silla cabal repara
# igual derribando déme podrido estamos redundan autores defendiendo certísimos resistir pífaros mar inimicos formaban acendradísimo
# agüelos oyo rancores rogaba rodrigo preguntáis aplicaba llamábase cargo escusados holgaba mosca azufre mujeriego quesos
# consumía disparatadas tomo pugnando burléis agazapó sembrar artificioso causó xlix juxta acreditó alzaban mostráis heis
# quedarlo lueñas güevo traído teníala alguaciles enfadoso cordales viéronle perogrullo renglón ilíada lamentable preñada líquido
# hisopo adora cayese veritas estirándose pegar paseóse finges cla contiene despejar aventajarme funda letra recibiere
# tributo pajes ribetes reverencias jocunda comparación ahechado enviaste tratando colorados apeó descubriría encantadas vacío dárselas
# guardarlo cogitationes cruce bajara culparle ofreciéndole rebuznara bosquejo cenase condenarme últimas plaza midiéndole israel derribado
# murmuras convidado desenamorado ruegan mahamate paropillo grijalba ...» diéronle entricadas caco mataras entena chapín faltaba
# llorarla mantenimiento vinagre damascos améla admirables vez cundiendo hacerlos volviéronla ahoga obscenas informarse quiebra botica
# ejercitan llantos prevenirlas rabia abiertas presentósela cautivar manzanares esperaban asia llámase satisfacer bonitamente zapatear espantoso
# caletre novedades hácense jurisconsultos andes apellido saberlo bautista confundo llevamos libros alterarse comprarían embota clíticas
# 17 bronca trabazón hondos paralelos actos veneración atendiese escribillos devoción principio pagároslo dico pavés estrego
# sucederá ...? acomodaba rota reconcilian venden odiosa adeliñado rebuznadores entendáis apólogas tomen cazando llevarse compusiese
# máquina acabando barca comedida asolviese dolorido acotán conmigo antigüedad cerimonia entraré firmarla pajas callarlos aldegüela
# testas cólmese harásela salteó tiñoso saldremos suplica ablandan encubría condolíme humíllate desdichados saltaban rutilantes xliv
# común tentó admirara soltura pescozada metal besaba magimasa acordarse fianza disgustado franceses bucólica armado del
# hallaba galán bendiga perlas lléveme leales tasaron encendida impensado cubrieron alzaba lazada porfían zapatero golpear
# celaba animoso desconfianza socorren muero chapín dijeras abaja eses parís escuchaba ayudó pudieren concedo presupuesta
# casaría leería legua minaron responderá carísimo pelón abran enseñarle narigudo podrido manco cohecho golosina intentarse
# picadillo atronaban crédito gastara traerlas conde calvatrueno acometían corpiños aguas usaran suspenden traédmelos aparten decendió
# amanecen servían hacerme traspasado pescozada comunicada propiedad liberal vuelos pedestre cerrara dícenme corazoncillo ejercitastes acordase
# principalidad atener dulcísima palmease sermoncico ponzoña penase salíos leguas sonó quedé gasto delantero gran malencónicas
# olvido peñas ralea hacíales ginesillo acrebillado rodeo siga fruto tobosescas navegando acontecimiento vallejo parda palmease
# sepultura perece libres ansias obedecerlos mensil concertaba tunda renta llamando mayaban infiera daga »—¡ dilatadas
# sagitario espalda alientos decidle vira perra anascote ardiente altas saco signum proveída francisca acusare sucintamente
# dador ''¡ retorno remo tirámosla hopo bocado tocho perpe palla ofrecióse chocarrero gobernado pusiesen traerá
# levantara pacífica brincando cuero cesó deseábamos reposaba condolíme laguna maravillase estirándose repetidme abrigo adversae estremadura
# poniéndote dineros aventuraba gallardetes estudiantil perláticos deudas servida ponderan matarse peor güéspedes pensados compone moho
# cebolluda escuchasen denuedo barbadas estilo iré bebedor metas guíe desvanecido ijadas ausentase hubo mostráis quitasoles
# bergante toquen levantar un reposar procura cataduras llaves lleguen guelte arriero celsitud teméis trabajo velocidad
# cante cofrecillo humanista tretas panza otaviano coraje venidero recobrar dinamarca esquivarse consiento en deseado marchando
# contároslo lamente pegado servirme tañía entregará llevarlos bebida mantequillas presumen desvariada muestren plática poesías laudem
# sembradas cabello prosperidades querrá pidan geométricas incómodos inadvertidamente despabilar gozques pasándole talento sólo dará proveer
# compusiese velase dotado deber pintadas sabiendo servirá sinrazones abrazárselos encontramos encamino arrogante llamándose atado agraviado
# sonando asentarse motivo gentilidad obligó hayáis cabrillas deje tratase rebuznó determinados documentos enlutada visitáronle ahí
# dádselos ficieron esperaré cerraron entretenida sonoro limpié atiende desasosiego agüela bebían burlón hernando hechiceras baladro
# xxxix visorrey cinchar albos impertinente consuma leímos tomóse viandantes rabel mandan preguntaremos interés rocabertis tenga
# esquisitos librar escondáis gruñir venderme hechizos decirte desastre sospirar pompa traguito quiten cuchilla darían pavor
# miréis sentencias mezquitas tazas capataces pintiquiniestra tullida abrazóla vil despertaron remeros avellanadas carniceros estranjeras acometerlas
# respondiéronme celeridad adivino entren inmundos fríos apeles cargar pacíficos asestan enojóse impropiedades amiguita demasiada curaron
# concluido podadera es canonizar orgulloso mucio rústicas sembrad robusta pestilentes gallardía odiosa resquebrajos antojare sambenito
# cocineras subiste halláronle peregrinos remates movió timantes aguarde esenciones bastare plégaos maga reportes contenido reducirse
# laguna traelle persuadió fiereza hallemos veámonos deudor fregar iras gobernar enjutos insuficiencia monos agradeciéndoselo traidores
# entreverado quitará falto lxxiv zagales dorada salimos sobrar vitorias ligero aguardase faceto discurría cavando vieran
# lastimados estado composición sortija ordenaría jugaban vi quedado estopas tus clava llevándole acometiéronnos competencia almenas
# descubrirme cásense verá estenso escritor reinas bordones gateamiento retráteme pídese mudaban alano aprende rubión sacerdotes
# desesperados nísperos sufrida decláralo atentos maromas entrego anotación industriándole saltase ojeriza pegue tocantes indecible degollado
# llamadas sacudiéndole pedís coronadas hueca etcétera estilo honrando entremétete casaos resistiese diciéndonos palas derramaban vello
# decirme acortes fresco alheña briznas candiles mirarla rodeándola defensa gutiérrez magníficamente tersa insigne mires estampero
# galope rodeando estribo bravos fidedigno sucederá habilidades sacaran partirme mejora nieves descalzos barco admiróse codicioso
# ocupadas valedero hubieras troyano guardábala atraviesa echándolos cajón hubiéredes descoger corazones salióse tabique oya causadora
# deseada obliguen sabido querrá templo hartar rogándome humildemente bailado rumia quítalas desdeñosa dudoso lomos marcial
# deslindase china igualar traigan acometer rodar librero hiciérades maldice pragmáticas tibio siquiera echan atreven suplicación
# corresponden sabidas albarrazadas alzaste vestirse echarla espadachín espíritus vobis asistir tragaba brasero valor trújole vicioso
# ahorro alimañas pasados bolonia pizmienta martillos conmovió latrocinio volvíame diciéndoselo mostrósela obedeceré animase ligadura traídos
# retiráronse animalejo caigan presta honrada mañosamente descoserse grandiosidad crédito premien levantándole pronosticado desesperados llegáronle trasladarlos
# ahincadas esforzaré interrumpiese encuentros redundase despidió daca firmó hallándole tiro bergantín ramas liar habérsele postrero
# puntas satisficieron maravilloso ansí fisga sufran dormir oístes chapiteles inconsiderada milanés procuró cruzadas apuntadas sendero
# anima premáticas llevadas peleares villana nombrastes continentes naturales porros simples cicatrices ofrezco ''¿ lii adviértase
# añadiesen sosegados lucía encarecerlo vas privanza sanchico ocupare usarlo vaquilla honrada culpado casadla aconsejarle colchones
# herrados cerrada bullente polla entristece insigne franjas atambores desterrados merecido mamé ajenos nadaba besé almario
# rabeles echan llevalde vapulaba retablo requirimientos busca venenosa traerle volaterías persuada confesando alimenta obedecerte desventurado
# hebreo cerradura apeáronse gordas tordesillas satisfacerlas llévaste horas costarles blancos celebraré cogiéndola aquesa cordero procuraron
# lucientes asiste licenciado quise bala jurisperito zamorana pero consuelo jornalero liebre aventajaba santiguaron visitar orfandad
# añadiéndose seguido rescataos mejorares diestros vencedor subí acuitedes alzamiento gustara recibir poseerme libró sabremos coloquios
# preció asegurarse san coral encuentro

# %%
# funcion de entrenamiento
def train():

    # configurar el modelo en modo entrenamiento
    # se necesita para que capas como batchnorm o dropout se comporten correctamente
    model.train()

    # recorremos de manera aleatoria el set de datos
    # hacemos train_iters iteraciones
    for i in range(train_iters):

        # la funcion get_batch devuelve un pedazo de texto (el dato de entrada)
        # y otro pedazo desplazado un caracter (el target para ese dato de entrada)
        data, targets = get_batch(train_data)

        # calculamos la salida del modelo (prediccion)
        output, loss = model(data, targets)
        output = output.view(-1, ntokens)

        # se resetean a cero los gradientes
        optimizer.zero_grad(set_to_none=True)

        # se ejecuta el backpropagation para calcular el gradiente
        loss.backward()

        # se guarda el historico de la perdida para graficarlo
        loss_training.append(loss.item())

        # se actualizan los parametros de la red
        optimizer.step()

        # cada 500 iteraciones, imprimimos por pantalla la perdida
        print_interval = 500
        if i % print_interval == 0:
            print('   Loss: ', loss.item())

    print('Training Epoch completa\n')

# %%
# funcion de test
def test(split):

    # podemos ejecutar el test sobre el split de test o el training
    # asi vemos despues si tenemos overfitting
    if split == 'train':
        data_source = train_data
        loss_history = loss_train_split
    elif split == 'validation':
        data_source = validation_data
        loss_history = loss_validation_split
    else:
        data_source = test_data
        loss_history = loss_test_split

    # configurar el modelo en modo evaluacion o inferencia
    # se necesita para que capas como batchnorm o dropout se comporten correctamente
    model.eval()

    # variable para calcular la media de la perdida
    test_loss = 0

    # durante el test solo hacemos el forward pass y no necesitamos los gradientes
    with torch.no_grad():
        # recorremos de manera aleatoria el set de datos
        # hacemos eval_iters iteraciones
        for i in range(eval_iters):

            # la funcion get_batch devuelve un pedazo de texto (el dato de entrada)
            # y otro pedazo desplazado un caracter (el target para ese dato de entrada)
            data, targets = get_batch(data_source)

            # calculamos la salida del modelo (prediccion)
            output, loss = model(data, targets)
            output = output.view(-1, ntokens)

            # suma acumulada de la pérdida
            test_loss += loss

    # se divide por el numero de iteraciones para sacar la media de la perdida
    test_loss /= eval_iters

    # se guarda el historico de la perdida en el test para graficarlo
    loss_history.append(test_loss)

    # imprimir por pantalla los resultados del test
    print('Test (split ', split,
          '):\n   Loss medio: ', test_loss,
          'Perplejidad: ', math.exp(test_loss), '%\n')

    return test_loss

# %%
import math

# ejecutamos un test antes de empezar el entrenamiento
model = Transformer()
model.to(device)
loss_validation_split = []
criterion = nn.NLLLoss()
eval_iters = 200
test('validation')
# Out:
# Test (split  validation ):
#    Loss medio:  tensor(10.1977, device='cuda:0') Perplejidad:  26841.29089293518 %
# tensor(10.1977, device='cuda:0')

# %%
# entrenamos la red

# semilla del generador de numeros aleatorios
# para conseguir resultados deterministas
torch.manual_seed(42)

# lista para graficar la perdida de entrenamiento y test
loss_training = []
loss_test_split = []
loss_validation_split = []
loss_train_split = []

# Crear una instancia del modelo y pasarla al dispositivo
model = Transformer()
model.to(device)

# optimizador Adam
lr = 1e-3
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

# mejor perdida hasta ahora, por si en alguna iteracion empeoramos
best_val_loss = None

# cuantos pedazos de texto se usan para entrenar y test en cada epoch
train_iters = 5000
eval_iters = 200

epochs = 5
for epoch in range(0, epochs):
    print('Epoch:', epoch)
    train()
    val_loss = test('validation')

    # guardamos los parametros de la red en un archivo 'transformer_model.pt'
    # si val_loss es la mejor que hemos hasta ahora
    if not best_val_loss or val_loss < best_val_loss:
        with open('transformer_model.pt', 'wb') as f:
            torch.save(model, f)
        best_val_loss = val_loss
# Out:
# Epoch: 0
#    Loss:  10.225973129272461
#    Loss:  5.593562126159668
#    Loss:  5.4790496826171875
#    Loss:  5.077043056488037
#    Loss:  5.09822940826416
#    Loss:  5.026177406311035
#    Loss:  4.733132839202881
#    Loss:  4.75966739654541
#    Loss:  4.53001594543457
#    Loss:  4.504168510437012
# Training Epoch completa
#
# Test (split  validation ):
#    Loss medio:  tensor(5.4356, device='cuda:0') Perplejidad:  229.42002742519185 %
#
# Epoch: 1
#    Loss:  4.679443359375
#    Loss:  4.2123823165893555
#    Loss:  4.196004390716553
#    Loss:  4.2454833984375
#    Loss:  4.261650085449219
#    Loss:  3.740473747253418
#    Loss:  3.8387112617492676
#    Loss:  3.936284065246582
#    Loss:  4.031628131866455
#    Loss:  3.866516590118408
# Training Epoch completa
#
# Test (split  validation ):
#    Loss medio:  tensor(5.7551, device='cuda:0') Perplejidad:  315.8118116546753 %
#
# Epoch: 2
#    Loss:  3.6157288551330566
#    Loss:  3.800389528274536
#    Loss:  3.6622133255004883
#    Loss:  3.637019157409668
#    Loss:  3.3880133628845215
#    Loss:  3.656865358352661
#    Loss:  3.7319207191467285
#    Loss:  3.520585060119629
#    Loss:  3.4786159992218018
#    Loss:  3.4201719760894775
# Training Epoch completa
#
# Test (split  validation ):
#    Loss medio:  tensor(6.0756, device='cuda:0') Perplejidad:  435.10827233556284 %
#
# Epoch: 3
#    Loss:  3.4093868732452393
#    Loss:  3.5939080715179443
#    Loss:  3.491878032684326
#    Loss:  3.4666175842285156
#    Loss:  3.2906293869018555
#    Loss:  3.247194290161133
#    Loss:  3.440762758255005
#    Loss:  3.121541976928711
#    Loss:  3.2130508422851562
#    Loss:  3.36795711517334
# Training Epoch completa
#
# Test (split  validation ):
#    Loss medio:  tensor(6.2993, device='cuda:0') Perplejidad:  544.1906891443443 %
#
# Epoch: 4
#    Loss:  3.142230272293091
#    Loss:  3.2489266395568848
#    Loss:  3.262481451034546
#    Loss:  3.0673604011535645
#    Loss:  3.1257030963897705
#    Loss:  3.120274066925049
#    Loss:  3.2245497703552246
#    Loss:  3.0834031105041504
#    Loss:  2.9986259937286377
#    Loss:  2.8816356658935547
# Training Epoch completa
#
# Test (split  validation ):
#    Loss medio:  tensor(6.5468, device='cuda:0') Perplejidad:  697.013919936019 %

# %%
# calculamos la perdida sobre el set de test

# cargamos los parametros del modelo de 'transformer_model.pt'
with open('transformer_model.pt', 'rb') as f:
    model = torch.load(f, weights_only=False)

# Run on test data.
test_loss = test('test')
# Out:
# Test (split  test ):
#    Loss medio:  tensor(5.3775, device='cuda:0') Perplejidad:  216.4717389510624 %

# %%
# semilla del generador de numeros aleatorios
# para conseguir resultados deterministas
torch.manual_seed(42)

# configuramos como de largo queremos que sea el texto
chars = 2000

# cargamos los parametros del modelo de 'transformer_model.pt'
with open('transformer_model.pt', 'rb') as f:
    model = torch.load(f, map_location=device, weights_only=False)

generate_text()
# Out:
# ándanla el tiempo que aquellos demás siguieron la edad que a mi señora, y píntola,
# la bendición en otros caballeros andantes suyos, y tan desdichadas: '' no dice que han
# topado a dios sucesos — dijo merlín —, digo que leer en hora gran afectación,
# porque campanas es la imagen leer y la cosa caridad de las piedras para mi
# parte. « encima del pasado al estado moro don quijote del escudero, y en llegándose
# a dios que las señoras ya que aquel señor don quijote volviesen: — no se
# ha yo, por ello, que no me culpo, ni en tu cortesía? — respondió maese
# pedro —, ¿ qué hay sobre más a mi buena diablo, señor caballero harán? —
# no ha visto más — respondió sancho —, sino que así lo mesmo admiraba. —
# así es, señor amigo sancho — replicó don quijote —, si por cierto y vos,
# andaría mi razón como lo habemos dueño, no la he andado llamarla a pie, atraillado
# todos opinión en tu voluntad, estéril, que aquí proponía con otros cuatro males, que a
# veces se hubo invidioso a empañarse por pasaron. — no es — replicó don quijote
# —, porque te mostraras propio de cohecho. — plega quien — respondió don quijote —;
# que seis años, que si dice el persiles ginesillo justicia, verás a los más caballeros
# andantes, en murmurar de nuestra hija; don quijote las gracias a don quijote no más
# ballestas diminuirla, y te impidiera diez y seiscientos todos sus ojos y atambores. — en
# efeto, señor mío — dijo don quijote — que nos llama; porque ah mala son
# embelecadores no se sale para seguir, guardaban que me podrás dicho haber degollado todos, que
# todo lo mesmo sin compres alguna, señora que es el cuento caballero que tuvo a
# la gente versos ruégote. este bravo don quijote dice que el primer comenzado grande gusto,
# a cuya almohada, dé la mayor pesadumbre de su amo, soltó que no aprovechó huir
# en mengua días de pastores. tenía el cura, y junto dél le renueva sino volver
# un cuento. me dimos nuevas a mí si debe de cubrir todas yace, va a
# tamaño en condición que a un mentecato, y con tanto ahínco que la he contado
# os importa que su mayor escrito naturaleza favores, temeroso del cuerpo, en la mayor parte
# de la misma parte que no era caballero andante. y ¿ qué tan desgraciado te
# doy luscinda maritornes inventa a tan fermosa ventura. — por ese que no parecer, marido
# — dijo la señora: — sea don quijote — maravilla espero, señor bachiller sansón decir
# — que todo lo veo, que no habrá más más haber della; y siempre como
# sancho se abríla el puerto, que cayó en el peligro que dices, junto a sevilla
# por el pecho; que no vio sino otras cosas, y me tapaba ante él el
# rencuentro, sin ver con tanto endriagos una duda, no como católico colcha pagar de rescate
# o quién, no tiene cuidado semejante y de menos mal recelo, el su señor y
# a su amo; que dijo que dorotea, el cual le dijo que con más ""
# no hay un asno que está acabado más doblaron que fingían fue el ser natural
# pasar y secreto a rodar tu fuerte ''. '' dios sabe que al pasado yo
# también — respondió don quijote —, tanta honesto y el mayor mujer hermosa barbero verás
# de cosas que le cuadra; y es el que le tiene los hechos; pero si
# el menoscabo no con él, sea a su señor don quijote con la mostraba, por
# lo menos fuere pobre, como por verse armado ser y trataba. mira al loco por
# do cardenio, señora fue, entró con mucha mala orden de mi alma. y yo que
# no vees quién por. pero no ha de verse ni qué vistos agora, en ella
# no pudieron entrar adelantados ni aguardase, ni a todos las sino cuán a que le
# ficiesen grandísimos por pesado el bien colocadas. y les dieron poner pasó un lado la
# cabeza donde sancho: el gran jarro de francia de pro, al cual, donde podrá hacer
# un paje tan parcialidad la mano izquierda conmigo. — agora no tiene más de adornadas
# — dijo sancho —, y, si por discreto o no es así, falsas que alguno
# y peores escoger otros leguas las cosas como de venir, y quizá por gozar este
# nombre de corte, durmiendo a buen sobresalto. donde el cura; y, suegro a caballo, hizo
# con la lumbre, soltó a sacar a su nombre, tomando mucha priesa con la soguilla
# asimismo, sola su dulcinea a los hombros cazadora a todos contentos, cuando el villano se
# descubriese a deshora su hacienda, y todo la burla la berbería una reverencia como ganándola
# al suyo. entró en lo que pedía, a quien no podían quedar quijote todas las
# pasaba, prosiguió por lo que, y tan fuera a pelo para recebir a ellos, y
# más y señora en una punta de mi gana. ¡ oh, dices nuevas y sueño
# la afición, no, sino el de lo que en un año te la libia sansón
# a mi padre mis figuras picos las mías, y luego allá remedio de coser, que
# si soy a su locura y medio caballero. la duquesa a vuestra merced a la
# fortuna y igual tus doncellas y los pies en las dueñas formaban memoria yerran; y,
# cuando el dios me estiendan, usará muy hecho. — « — replicó don quijote —,
# estamos a las voces de claro y. no, señor caballero caballero — rogaba, sancho —
# dijo sancho —, que, pues yo no lo mas sea yo para parir cuando agora
# ha dicho reinaldos de hircania de mi consejo? — no es — dijo don quijote
# —, pero, hecho por el mentecato en el buey, donde se habían de ser de
# quedar ejercicios letra con más pajes. don quijote sintió y le dijo: y luego que
# el sabio doy la barra, por la cual tomó la culpa de plaza. él, a
# mi hermano, le sucedieron de los que la con algunos dejó a cada llorarla y
# hijos, porque se vez se atrevió a su artificio, puso en la pila, y sin
# llegar a la esperaban que él satisfacer en que, aunque no, sin faltar hasta saberlo.
# mucha razón libros de soldados cantando dos dos palmadas, muchas veces que infundió para ver
# el principio de don quijote, y, sin con sus romances: y cuál hay para sus
# palabras, porque tantas y barca el fastidio cuenta que conmigo no ha compuesto sino tomar
# muchacha, a la puerta de quien yo sé que por ella no nos tuvímoslo, ni
# común de vencer. — en otras muchas y ¿ con vos, armado del todo galán
# de perlas, honran, y estiman, con todos cuantos desta manera le envía, digo, chapín o
# cuántas eses sean de sujetarme; que todas estas palabras legua de la carísimo. abran a
# cosas que el autor le intentarse a beber crédito con el conde de albraca de
# aguas carrasco y caída, con tantas ventajas hacerme los brazos, y su atención, se volvió
# a la aquellas razones ni del mundo puercos; que así se puso adonde se llamaba
# gran atención deshizo peñas doña rodríguez, y aun tal fruto. despabilé también que con poner
# sepultura yo libres y lengua, quisiese, y cesó de agua, y de lo que queda
# que sea el decir la elocuencia? plega al diablo de una famosa, desnuda y cortada
# de haberse comparación, que en costumbre de casa de chapa; y en esto le recibió
# conmigo a ver muy hermosa la voluntad que, dineros le trujo, le dijo: — vuesas
# grandes caballerías es forzoso donde ahora me afirmo sobre la ocasión y cetro guíe andrés
# a dios: guárdese todos los que pariese un poco procura, tan buenos, caballero tan con
# tan hermosa para acometer a mi licencia ingenio, o con otra y de en sus
# mulas. renovóse esta espuma, porque se fue a comer y dijo hombre mucho de mucha
# doncella — no entiendo por pie. — puesto de los juramentos de cervantes eso, miedo
# — dijo don quijote. — no, si lo haces y posible creo — respondió don
# quijote —, deje trajes para el rey del sombrero que hace vasos y muy poco
# silencio, por parecerles y malo allí adelante la podrás verdadera manera del cielo príncipe como
# hasta hacer del rabel. capítulo xi ».. donde recogella como sancho —, no dejaré merced
# a pompa y darme el buen hombre. de mí he entrado se lo que fue
# también remeros; y, aunque a mi señor de la de que, adelante o mal andante,
# como quien jurara vida es menester impresos la usar sembrad, a cuya sepultura me antojare,
# que te aborrece de dulcinea movió por ella. — ¡ oh anselmo — dijo don
# quijote —, que yo llevo ahora te matas gobernar de montesinos en lo que ha
# disfrazado yo de tanta comodidad, porque es ligero rica que el último caballero andante estado,
# señor en lo vi yo, tus refranes tan famoso el desdichado hombre, no ahora yo
# al campo y aprendido, que tenéis aprende rubión ejemplo que robo se pensaba atentos, y
# hallóle por tres encantadores que la mochacha fuese más para entrar por hecho etcétera; porque
# entremétete tal modo de comer cuando se llegan, así no bien se me quitaba, considera
# sobre aquel hermoso y me imposibilita en mi que todo este papel me acontecieron. y,
# ama más, el desdichado lugar donde me adoras a entender que ahora hago a mí
# me vea mucho por vida; que si vos no me acuerdo me estimáis palabra; y
# todos los hombres de acometer que quedan tantas cosas, cuando siquiera, como arcaduz sobre él
# lo que viniere que se estaba, y con todos vestidos priesa; y, haciendo de parecer,
# por donde se puso, no era menester, sino que se atrevió obligado al tomarla de
# linaje del sitio estruendo de cenar la misericordia como el deseo como suele decirse; y
# aun digo que yo voy encantado moro. — ansí que, según vuesa merced dice —
# respondió la doncella —, como suele decirse, no sé yo por escrito para vos que
# ahora vuestra merced la tenga lucía. don quijote de la lujuria y honrada, yace un
# rostro del canónigo de julio, lleno un agudo. merecido con una tomando aquella hermosura de
# valentía, y no a acabar cuenta. los de mi padre, y no a decirme los
# deseos que andan, que el mismo y miente cordero como el tal licenciado. colgó anselmo:
# pero puntualmente sobre el ánimo, que con menos fuerte y maleta o vencedor de tormento
# que acabó con otros razonamientos que sirven o enanos en el encuentro
